# %%
import cv2 as cv
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Core

# %%
FACE_CASCADE = cv.CascadeClassifier('/mnt/data/deepfake/haarcascade_frontalface_default.xml')

# %%
face_folder = '/home/filouface/deepfake/datasets/faces/'

# %%
def extract_face_from_frame(frame):    
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    faces = FACE_CASCADE.detectMultiScale(gray, 1.1, 4)
    x, y, w, h = faces[0]
    return frame[y:y+h, x:x+w]

# %%
def process_video(video, dest_path):
    cap = cv.VideoCapture(video)
    i = 0
    while True:
        has_next, frame = cap.read()
        if not has_next:
            break
        
        pic = extract_face_from_frame(frame)
        save_path = dest_path + os.path.basename(video) + '_' + str(i) + '.jpg'
        cv.imwrite(save_path, pic )
        i += 1
        
    cap.release()

# %%
def process_folder(path):
    for i, vid in enumerate(os.listdir(path)):
        video_path = face_folder+os.path.basename(path[:-1]) + '/'
        print(i)
        process_video(path+vid, video_path)

# %%
def process_dataset(path):
    pass

# %% [markdown]
# # Getting things done

# %%
process_folder('/home/filouface/deepfake/datasets/ravdess/Actor_01/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-8da1606dd608> in <module>
# ----> 1 process_folder('/home/filouface/deepfake/datasets/ravdess/Actor_01/')
#
# <ipython-input-7-14cc798efe90> in process_folder(path)
#       1 def process_folder(path):
# ----> 2     for i, vid in enumerate(os.listdir(path)):
#       3         video_path = face_folder+os.path.basename(path[:-1]) + '/'
#       4         print(i)
#       5         process_video(path+vid, video_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/filouface/deepfake/datasets/ravdess/Actor_01/'

# %%
os.path.basename('/home/filouface/deepfake/datasets/ravdess/Actor_01/')
# Out:
# ''

# %%
cap = cv.VideoCapture('/home/filouface/deepfake/datasets/ravdess/Actor_02/01-01-01-01-01-01-02.mp4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5945f3ea4842> in <module>
# ----> 1 cap = cv.VideoCapture('/home/filouface/deepfake/datasets/ravdess/Actor_02/01-01-01-01-01-01-02.mp4')
#
# NameError: name 'cv' is not defined

# %%
_, pic = cap.read()

# %%
plt.imshow(pic)
